# %%
# !pip install ultralytics gdown -q

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'
# !wandb off
# Out:
# W&B offline. Running your script from this directory will only write metadata locally. Use wandb disabled to completely turn off W&B.

# %%
# !gdown 11bOBn_EiZ6BPNEaFXp28dT6uKa4ymoLR
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11bOBn_EiZ6BPNEaFXp28dT6uKa4ymoLR
# From (redirected): https://drive.google.com/uc?id=11bOBn_EiZ6BPNEaFXp28dT6uKa4ymoLR&confirm=t&uuid=24585979-fadf-4d04-8fb5-21885d979403
# To: /kaggle/working/comsocdata.zip
# 100%|██████████████████████████████████████| 44.3M/44.3M [00:04<00:00, 8.99MB/s]

# %%
# !unzip -q /kaggle/working/comsocdata.zip -d data_final

# %%
# !yolo classify train data=/kaggle/working/data_final/model_data/ model=yolov8s-cls.pt epochs=1000 patience=200 int8=True plots=True
# Out:
# ...
# 100%|██████████████████████████████████████| 12.3M/12.3M [00:00<00:00, 54.8MB/s]
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !yolo export model=/kaggle/working/runs/classify/train/weights/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# YOLOv8s-cls summary (fused): 73 layers, 5,080,324 parameters, 0 gradients, 12.5 GFLOPs
#
# PyTorch: starting from '/kaggle/working/runs/classify/train/weights/best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 4) (9.8 MB)
#
# ONNX: starting export with onnx 1.16.2 opset 19...
# ONNX: export success ✅ 0.4s, saved as '/kaggle/working/runs/classify/train/weights/best.onnx' (19.4 MB)
#
# Export complete (2.4s)
# Results saved to /kaggle/working/runs/classify/train/weights
# Predict:         yolo predict task=classify model=/kaggle/working/runs/classify/train/weights/best.onnx imgsz=224
# Validate:        yolo val task=classify model=/kaggle/working/runs/classify/train/weights/best.onnx imgsz=224 data=/kaggle/working/data_final/model_data/
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export
